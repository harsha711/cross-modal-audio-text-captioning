# %% [markdown]
# # Train Baseline Model (Memory-Efficient for 8GB GPU)
#
# This notebook trains a **memory-optimized** baseline CNN-LSTM model.
#
# **Optimizations for 8GB GPU**:
# - Smaller embedding dimension (128 vs 256)
# - Smaller hidden dimension (256 vs 512)
# - Fewer LSTM layers (1 vs 2)
# - Moderate batch size (16 vs 32)
#
# **Model**: CNN encoder + LSTM decoder
#
# **Estimated time**: 2-4 hours (30 epochs on GPU)

# %% [markdown]
# ## Step 1: Setup and Imports

# %%
import os
os.environ['MKL_THREADING_LAYER'] = 'GNU'  # Fix threading issue
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'  # Better memory allocation

import sys
from pathlib import Path

# Add parent directory to path
project_root = Path('..').absolute()
sys.path.insert(0, str(project_root))

import torch
torch.cuda.empty_cache()
import gc
gc.collect()

import json
from src.models import create_model
from src.dataset import create_dataloaders
from src.trainer import ModelTrainer
from src.utils import load_vocab, set_seed, get_device, count_parameters, make_json_serializable


print("✓ Imports successful!")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# ✓ Imports successful!
# PyTorch version: 2.7.1+cu118
# CUDA available: True

# %% [markdown]
# ## Step 2: Set Random Seed and Check GPU

# %%
set_seed(42)
device = get_device()

# Check GPU memory
if torch.cuda.is_available():
    total_memory = torch.cuda.get_device_properties(0).total_memory / 1024**3
    free_memory = torch.cuda.mem_get_info()[0] / 1024**3
    print(f"\nGPU: {torch.cuda.get_device_name(0)}")
    print(f"Total GPU memory: {total_memory:.2f} GB")
    print(f"Free GPU memory: {free_memory:.2f} GB")
else:
    print("\n⚠️ No GPU available, using CPU (will be slower)")
# Out:
# Random seed set to 42
# Using device: cuda (NVIDIA GeForce RTX 3070 Ti Laptop GPU)
#
# GPU: NVIDIA GeForce RTX 3070 Ti Laptop GPU
# Total GPU memory: 7.66 GB
# Free GPU memory: 7.43 GB

# %% [markdown]
# ## Step 3: Load Vocabulary

# %%
print("Loading vocabulary...")
vocab = load_vocab('../vocab.json')
print(f"\n✓ Vocabulary size: {len(vocab)}")
print(f"  <pad>: {vocab['<pad>']}")
print(f"  <sos>: {vocab['<sos>']}")
print(f"  <eos>: {vocab['<eos>']}")
print(f"  <unk>: {vocab['<unk>']}")
# Out:
# Loading vocabulary...
# Vocabulary loaded from ../vocab.json (size: 5986)
#
# ✓ Vocabulary size: 5986
#   <pad>: 0
#   <sos>: 1
#   <eos>: 2
#   <unk>: 3

# %% [markdown]
# ## Step 4: Create Dataloaders with Reduced Batch Size

# %%
print("Creating dataloaders...")
print("Using batch_size=16 (optimized for 8GB GPU)\n")

train_loader, val_loader, eval_dataset = create_dataloaders(
    train_captions='../data/train_captions.json',
    val_captions='../data/val_captions.json',
    eval_captions='../data/eval_captions.json',
    train_features_dir='../features/mel/',
    val_features_dir='../features/mel/',
    eval_features_dir='../features/mel_eval/',
    vocab=vocab,
    batch_size=16,     # Reduced for memory efficiency
    num_workers=2       # Also reduced
)

print(f"\n✓ Dataloaders created:")
print(f"  Train batches: {len(train_loader)}")
print(f"  Val batches: {len(val_loader)}")
print(f"  Eval samples: {len(eval_dataset)}")
# Out:
# Creating dataloaders...
# Using batch_size=16 (optimized for 8GB GPU)
#
# Loaded 3839 samples from ../data/train_captions.json
# Loaded 1045 samples from ../data/val_captions.json
# Loaded 1045 samples for evaluation
#
# ✓ Dataloaders created:
#   Train batches: 239
#   Val batches: 66
#   Eval samples: 1045

# %% [markdown]
# ## Step 5: Create Memory-Efficient Baseline Model

# %%
print("Creating MEMORY-EFFICIENT baseline model...\n")
print("Model configuration (optimized for 8GB GPU):")
print("  - Embedding dimension: 128 (reduced from 256)")
print("  - Hidden dimension: 256 (reduced from 512)")
print("  - LSTM layers: 1 (reduced from 2)")
print("\nThis reduces memory usage from ~6GB to ~2GB\n")

model = create_model(
    'baseline', 
    vocab_size=len(vocab),
    embed_dim=128,      # Reduced from 256
    hidden_dim=256,     # Reduced from 512
    num_layers=1        # Reduced from 2
)

print("\nModel architecture:")
print(model)

print("\nParameter count:")
total_params, trainable_params = count_parameters(model)

# Estimate memory
model_memory = total_params * 4 / (1024**3)  # 4 bytes per param (float32)
print(f"\nEstimated model memory: {model_memory:.2f} GB")

# Move to GPU and check actual usage
print("\nMoving model to GPU...")
model = model.to(device)

if torch.cuda.is_available():
    allocated = torch.cuda.memory_allocated() / 1024**3
    reserved = torch.cuda.memory_reserved() / 1024**3
    free = torch.cuda.mem_get_info()[0] / 1024**3
    
    print(f"\nGPU Memory Status After Loading Model:")
    print(f"  Allocated: {allocated:.2f} GB")
    print(f"  Reserved: {reserved:.2f} GB")
    print(f"  Free: {free:.2f} GB")
    
    if free > 3:
        print(f"\n✓ Model fits comfortably in GPU memory! ({free:.2f} GB free)")
    elif free > 1:
        print(f"\n✓ Model fits in GPU memory! ({free:.2f} GB free)")
    else:
        print(f"\n⚠️ Low memory warning: only {free:.2f} GB free")
# Out:
# Creating MEMORY-EFFICIENT baseline model...
#
# Model configuration (optimized for 8GB GPU):
#   - Embedding dimension: 128 (reduced from 256)
#   - Hidden dimension: 256 (reduced from 512)
#   - LSTM layers: 1 (reduced from 2)
#
# This reduces memory usage from ~6GB to ~2GB
#
#
# Model architecture:
# BaselineModel(
#   (encoder): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): ReLU()
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): ReLU()
#     (11): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (encoder_projection): Linear(in_features=768000, out_features=256, bias=True)
#   (embedding): Embedding(5986, 128, padding_idx=0)
#   (decoder_lstm): LSTM(128, 256, batch_first=True)
#   (output_projection): Linear(in_features=256, out_features=5986, bias=True)
# )
#
# Parameter count:
# Total parameters: 199,678,690
# Trainable parameters: 199,678,690
#
# Estimated model memory: 0.74 GB
#
# Moving model to GPU...
#
# GPU Memory Status After Loading Model:
#   Allocated: 0.74 GB
#   Reserved: 0.76 GB
#   Free: 6.64 GB
#
# ✓ Model fits comfortably in GPU memory! (6.64 GB free)

# %% [markdown]
# ## Step 6: Create Trainer

# %%
print("Initializing trainer...")

trainer = ModelTrainer(
    model=model,
    vocab=vocab,
    device=device,
    model_name='baseline_small'  # Different name to distinguish from full-size model
)

print("✓ Trainer ready!")
# Out:
# Initializing trainer...
# ✓ Trainer ready!

# %% [markdown]
# ## Step 7: Train Model
#
# **This will take 2-4 hours on GPU**
#
# Progress will be shown with:
# - Training loss per batch (progress bar)
# - Validation loss per epoch
# - Sample generations every 5 epochs
# - Learning rate changes
# - Early stopping if no improvement

# %%
print("Starting training...\n")
print("="*80)
print("BASELINE MODEL TRAINING (Memory-Efficient Version)")
print("="*80)
print("\nTraining smaller baseline model optimized for 8GB GPU")
print("Expected training time: 2-4 hours")
print("\nMonitor GPU memory during training:")
print("  watch -n 1 nvidia-smi")
print("\n" + "="*80 + "\n")

history = trainer.fit(
    train_loader=train_loader,
    val_loader=val_loader,
    eval_dataset=eval_dataset,
    num_epochs=30,
    learning_rate=1e-3,
    weight_decay=1e-5,
    patience=5,
    label_smoothing=0.0,
    save_dir='../checkpoints'
)

print("\n✓ Training complete!")
# Out:
# Starting training...
#
# ================================================================================
# BASELINE MODEL TRAINING (Memory-Efficient Version)
# ================================================================================
#
# Training smaller baseline model optimized for 8GB GPU
# Expected training time: 2-4 hours
#
# Monitor GPU memory during training:
#   watch -n 1 nvidia-smi
#
# ================================================================================
#
#
# ============================================================
# Epoch 1/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:47<00:00,  5.04it/s, loss=5.1739]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.88it/s]
# Train Loss: 5.7923
# Val Loss:   5.2315
# LR:         0.001000
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 2/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:47<00:00,  5.03it/s, loss=4.3404]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.63it/s]
# Train Loss: 4.9469
# Val Loss:   4.8974
# LR:         0.001000
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 3/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.98it/s, loss=4.4543]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.14it/s]
# Train Loss: 4.6500
# Val Loss:   4.6512
# LR:         0.001000
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 4/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.98it/s, loss=4.5677]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.43it/s]
# Train Loss: 4.4242
# Val Loss:   4.5430
# LR:         0.001000
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 5/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.95it/s, loss=4.3818]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.26it/s]
# Train Loss: 4.2359
# Val Loss:   4.3921
# LR:         0.001000
#
# Sample Generations:
# ------------------------------------------------------------
# 1. Ground Truth: A machine whines and squeals while rhythmically punching or stamping.
#    Generated:    a person is walking on a hard surface and a car drives by.
#
# 2. Ground Truth: A radio dispatcher and an officer are communicating over the radio.
#    Generated:    a person is walking on a hard surface and a car drives by.
#
# 3. Ground Truth: A radio tuner has been positioned in between radio stations to generate horrific static.
#    Generated:    a person is walking on a hard surface and a car drives by.
#
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 6/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.92it/s, loss=3.6571]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.20it/s]
# Train Loss: 4.0938
# Val Loss:   4.3078
# LR:         0.001000
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 7/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.94it/s, loss=4.0463]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.05it/s]
# Train Loss: 3.9950
# Val Loss:   4.2641
# LR:         0.001000
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 8/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.92it/s, loss=4.1864]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.30it/s]
# Train Loss: 3.8609
# Val Loss:   4.1993
# LR:         0.001000
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 9/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:47<00:00,  5.05it/s, loss=3.4613]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.93it/s]
# Train Loss: 3.7369
# Val Loss:   4.1650
# LR:         0.001000
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 10/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:47<00:00,  5.03it/s, loss=3.4054]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 20.01it/s]
# Train Loss: 3.6775
# Val Loss:   4.1101
# LR:         0.001000
#
# Sample Generations:
# ------------------------------------------------------------
# 1. Ground Truth: A machine whines and squeals while rhythmically punching or stamping.
#    Generated:    a person is walking through a gravel path and a person is walking on a hard surface.
#
# 2. Ground Truth: A radio dispatcher and an officer are communicating over the radio.
#    Generated:    a person is walking through a gravel path and a person is walking on a hard surface.
#
# 3. Ground Truth: A radio tuner has been positioned in between radio stations to generate horrific static.
#    Generated:    a person is walking on a gravel path and then a car drives by.
#
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 11/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.93it/s, loss=3.3315]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.14it/s]
# Train Loss: 3.6113
# Val Loss:   4.1726
# LR:         0.001000
#
# ============================================================
# Epoch 12/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:49<00:00,  4.88it/s, loss=3.3693]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.18it/s]
# Train Loss: 3.5369
# Val Loss:   4.1116
# LR:         0.001000
#
# ============================================================
# Epoch 13/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.91it/s, loss=3.6178]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.19it/s]
# ⚡ Learning rate reduced: 0.001000 → 0.000500
#
# Train Loss: 3.4698
# Val Loss:   4.1130
# LR:         0.000500
#
# ============================================================
# Epoch 14/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:49<00:00,  4.86it/s, loss=3.2298]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 18.68it/s]
# Train Loss: 3.3717
# Val Loss:   4.0747
# LR:         0.000500
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 15/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.88it/s, loss=3.0071]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 18.90it/s]
# Train Loss: 3.3300
# Val Loss:   4.0499
# LR:         0.000500
#
# Sample Generations:
# ------------------------------------------------------------
# 1. Ground Truth: A machine whines and squeals while rhythmically punching or stamping.
#    Generated:    a person is walking on a hard surface while a person is walking in the background.
#
# 2. Ground Truth: A radio dispatcher and an officer are communicating over the radio.
#    Generated:    a person is walking on a hard surface while a person is walking in the background.
#
# 3. Ground Truth: A radio tuner has been positioned in between radio stations to generate horrific static.
#    Generated:    a person is walking on a hard surface while a person is walking in the background.
#
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 16/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.90it/s, loss=3.5567]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.19it/s]
# Train Loss: 3.2655
# Val Loss:   4.0005
# LR:         0.000500
# Model saved to ../checkpoints/best_baseline_small.pth
# ✓ New best model saved!
#
# ============================================================
# Epoch 17/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.91it/s, loss=3.3061]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 18.98it/s]
# Train Loss: 3.2255
# Val Loss:   4.0651
# LR:         0.000500
#
# ============================================================
# Epoch 18/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.94it/s, loss=3.1557]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.64it/s]
# Train Loss: 3.2119
# Val Loss:   4.0377
# LR:         0.000500
#
# ============================================================
# Epoch 19/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:47<00:00,  5.00it/s, loss=2.8894]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.71it/s]
# ⚡ Learning rate reduced: 0.000500 → 0.000250
#
# Train Loss: 3.1606
# Val Loss:   4.0321
# LR:         0.000250
#
# ============================================================
# Epoch 20/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:47<00:00,  5.00it/s, loss=2.8598]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.00it/s]
# Train Loss: 3.1294
# Val Loss:   4.0347
# LR:         0.000250
#
# Sample Generations:
# ------------------------------------------------------------
# 1. Ground Truth: A machine whines and squeals while rhythmically punching or stamping.
#    Generated:    a person is walking on a hard surface and a person is walking on a hard surface.
#
# 2. Ground Truth: A radio dispatcher and an officer are communicating over the radio.
#    Generated:    a person is walking on a hard surface and a person is walking on a hard surface.
#
# 3. Ground Truth: A radio tuner has been positioned in between radio stations to generate horrific static.
#    Generated:    a person is walking on a hard surface and a person is walking on a hard surface.
#
#
# ============================================================
# Epoch 21/30
# ============================================================
# Training baseline_small: 100%|██████████| 239/239 [00:48<00:00,  4.94it/s, loss=3.1430]
# Validating: 100%|██████████| 66/66 [00:03<00:00, 19.28it/s]
# Train Loss: 3.1243
# Val Loss:   4.0596
# LR:         0.000250
#
# Early stopping after 21 epochs
#
# ============================================================
# Training Complete!
# Best Validation Loss: 4.0005
# ============================================================
#
# ✓ Training complete!

# %% [markdown]
# ## Step 8: Plot Training History

# %%
from src.utils import plot_training_history
import matplotlib.pyplot as plt

print("Plotting training history...")
plot_training_history(history)
plt.show()

# Save history
with open('../results/baseline_small_history.json', 'w') as f:
    json.dump(history, f, indent=2)
print("\n✓ History saved to results/baseline_small_history.json")
# Out:
# Plotting training history...
# ✓ History saved to results/baseline_small_history.json

# %% [markdown]
# ## Step 9: Final Evaluation

# %%
from src.evaluation import evaluate_model

print("Running final evaluation...\n")

results, captions, refs = evaluate_model(
    trainer.model,
    eval_dataset,
    vocab,
    device=device,
    num_samples=100
)

# Save results
serializable_results = make_json_serializable(results)
with open('../results/baseline_small_results.json', 'w') as f:
    json.dump(serializable_results, f, indent=2)


print("\n✓ Results saved to results/baseline_small_results.json")
# Out:
# Running final evaluation...
#
# Evaluating on 100 samples...
# 100%|██████████| 100/100 [00:00<00:00, 120.86it/s]
# ============================================================
# EVALUATION RESULTS
# ============================================================
# num_samples............................. 100
# avg_repetition_rate..................... 0.3583
# vocabulary_diversity.................... 0.0080
# unique_words_used....................... 13
# total_words_generated................... 1629
# mean_caption_length..................... 16.2900
# std_caption_length...................... 0.4538
# min_caption_length...................... 16
# max_caption_length...................... 17
# ============================================================
#
# ✓ Results saved to results/baseline_small_results.json

# %% [markdown]
# ## Step 10: Show Sample Predictions

# %%
from src.evaluation import get_sample_predictions, print_sample_predictions

print("Generating sample predictions...\n")

samples = get_sample_predictions(
    trainer.model,
    eval_dataset,
    vocab,
    device=device,
    num_samples=10
)

print_sample_predictions(samples, num_to_print=10)

# %% [markdown]
# ## Summary

# %%
print("\n" + "="*80)
print("TRAINING SUMMARY")
print("="*80)

print(f"\nModel: Baseline (Memory-Efficient)")
print(f"  - Embedding dim: 128")
print(f"  - Hidden dim: 256")
print(f"  - LSTM layers: 1")
print(f"  - Parameters: {total_params:,}")

print(f"\nBest validation loss: {min(history['val_loss']):.4f}")

print(f"\nEvaluation metrics:")
print(f"  - Repetition rate: {results['avg_repetition_rate']:.4f}")
print(f"  - Vocabulary diversity: {results['vocabulary_diversity']:.4f}")
print(f"  - Mean caption length: {results['mean_caption_length']:.2f} words")

print(f"\nFiles saved:")
print(f"  ✓ ../checkpoints/best_baseline_small.pth")
print(f"  ✓ ../results/baseline_small_history.json")
print(f"  ✓ ../results/baseline_small_results.json")

print("\n" + "="*80)
print("Next: Train attention model with 03_train_attention.ipynb")
print("="*80)
